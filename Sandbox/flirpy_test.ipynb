# %%
import flirpy
from flirpy import util, io, camera

seq_file = "C:\\Users\\U361220\\Desktop\\SEQ Conversion\\Videos\\TermovisionDamage1.seq"

# %%
help(flirpy)
# Out:
# Help on package flirpy:
#
# NAME
#     flirpy
#
# PACKAGE CONTENTS
#     camera (package)
#     io (package)
#     util (package)
#
# FILE
#     c:\users\u361220\appdata\local\anaconda3\envs\flir-sdk\lib\site-packages\flirpy\__init__.py

# %%
help(util)
# Out:
# Help on package flirpy.util in flirpy:
#
# NAME
#     flirpy.util
#
# PACKAGE CONTENTS
#     encode
#     exiftool
#     raw
#
# FILE
#     c:\users\u361220\appdata\local\anaconda3\envs\flir-sdk\lib\site-packages\flirpy\util\__init__.py

# %%
help(camera)
# Out:
# Help on package flirpy.camera in flirpy:
#
# NAME
#     flirpy.camera
#
# PACKAGE CONTENTS
#     boson
#     core
#     lepton
#     tau
#     tau_config
#     threadedboson
#     threadedcamera
#     timedservice
#
# FILE
#     c:\users\u361220\appdata\local\anaconda3\envs\flir-sdk\lib\site-packages\flirpy\camera\__init__.py

# %%
help(io)
# Out:
# Help on package flirpy.io in flirpy:
#
# NAME
#     flirpy.io
#
# PACKAGE CONTENTS
#     fff
#     seq
#     teax
#
# FILE
#     c:\users\u361220\appdata\local\anaconda3\envs\flir-sdk\lib\site-packages\flirpy\io\__init__.py

# %%
from io import *

# %%
io.__dict__
# Out:
# {'__name__': 'flirpy.io',
#  '__doc__': None,
#  '__package__': 'flirpy.io',
#  '__loader__': <_frozen_importlib_external.SourceFileLoader at 0x246def67730>,
#  '__spec__': ModuleSpec(name='flirpy.io', loader=<_frozen_importlib_external.SourceFileLoader object at 0x00000246DEF67730>, origin='c:\\Users\\U361220\\AppData\\Local\\anaconda3\\envs\\flir-sdk\\lib\\site-packages\\flirpy\\io\\__init__.py', submodule_search_locations=['c:\\Users\\U361220\\AppData\\Local\\anaconda3\\envs\\flir-sdk\\lib\\site-packages\\flirpy\\io']),
#  '__path__': ['c:\\Users\\U361220\\AppData\\Local\\anaconda3\\envs\\flir-sdk\\lib\\site-packages\\flirpy\\io'],
#  '__file__': 'c:\\Users\\U361220\\AppData\\Local\\anaconda3\\envs\\flir-sdk\\lib\\site-packages\\flirpy\\io\\__init__.py',
#  '__cached__': 'c:\\Users\\U361220\\AppData\\Local\\anaconda3\\envs\\flir-sdk\\lib\\site-packages\\flirpy\\io\\__pycache__\\__init__.cpython-310.pyc',
#  '__builtins__': {'__name__': 'builtins',
# ...

# %%
import cv2
cv2.__dict__
# Out:
# {'__name__': 'cv2',
#  '__doc__': '\nOpenCV Python binary extension loader\n',
#  '__package__': 'cv2',
#  '__loader__': <_frozen_importlib_external.SourceFileLoader at 0x246df22a830>,
#  '__spec__': ModuleSpec(name='cv2', loader=<_frozen_importlib_external.SourceFileLoader object at 0x00000246DF22A830>, origin='c:\\Users\\U361220\\AppData\\Local\\anaconda3\\envs\\flir-sdk\\lib\\site-packages\\cv2\\__init__.py', submodule_search_locations=['c:\\Users\\U361220\\AppData\\Local\\anaconda3\\envs\\flir-sdk\\lib\\site-packages\\cv2']),
#  '__path__': ['c:\\Users\\U361220\\AppData\\Local\\anaconda3\\envs\\flir-sdk\\lib\\site-packages\\cv2'],
#  '__file__': 'c:\\Users\\U361220\\AppData\\Local\\anaconda3\\envs\\flir-sdk\\lib\\site-packages\\cv2\\__init__.py',
#  '__cached__': 'c:\\Users\\U361220\\AppData\\Local\\anaconda3\\envs\\flir-sdk\\lib\\site-packages\\cv2\\__pycache__\\__init__.cpython-310.pyc',
#  '__builtins__': {'__name__': 'builtins',
# ...
